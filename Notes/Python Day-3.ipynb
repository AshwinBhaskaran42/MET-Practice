# %%
#3.1.3.5 - Checking string content

text= "HELLO123 "

# print(text.isalnum())
# print(text.isdigit())
# print(text.isupper())
# #text= text.upper()
# print(text.islower())

print(text.isspace())
# Out:
# False

# %%
#3.1.4.0 - String formatting

#name= "Subash"
#sentence = "Dear subash, your invoice is pending"
#sentence= f"Dear {name, name}, your invoice is pending" #Dear ('Subash', 'Subash'), your invoice is pending


# name= "John"
# amount= 5000

#using f-string (python 3.6+)
# sentence= f"Dear {name + ' kumar'}, your invoice of Rs.{5+ amount -1} is pending" #Dear John Kumar, your invoice of Rs.5004 is pending

#using format method:
#sentence= "Dear {}, your invoice of Rs.{} is pending".format(name, amount) #Dear John, your invoice of Rs.5000 is pending
#sentence= "Dear {1}, your invoice of Rs.{0} is pending".format(name, amount) #Dear 5000, your invoice of Rs.John is pending

#sentence= "Dear {name}, your invoice of Rs.{amount} is pending".format(name="charlie", amount=1000) #Dear charlie, your invoice of Rs.1000 is pending


#print(sentence)

# %%
#Unpacking Values into Multiple Variables

#a, b, c = 2,4,6,8,10 #too many values to unpack
a, *b, c = 2,4,6,8,10 # 2 [4, 6, 8] 10
# multiple stars not allowed
print(a,b,c)
# Out:
# 2 [4, 6, 8] 10

# %%
#Multi-line strings """....."""
email= """Dear Sanjay, 

how are you?

Thanks, John"""
print(email)
# Out:
# Dear Sanjay,
#
# how are you?
#
# Thanks, John

# %%
#3.1.4.1 - Escape characters

# sentence = 'It\'s a rainy day' # It's a rainy day
sentence = 'It\'s \na \nrainy \nday'    # It's 
                                        # a 
                                        # rainy 
                                        # day

sentence = 'It\'s \ta rainy day'   #It's 	a rainy day
            
print(sentence)
# Out:
# It's 	a rainy day
