# %%
# #BAMALIC Operators
# bitwise
# arithmetic
# membership
# assignment
# logical
# identity
# comparision

# %%
# Arithmetic operators

a, b= -10,2

print(a+b) # addition
print(a-b) # subtraction
print(a*b) # multiplication
print(a/b) # Division - quotient
print(a//b) # FLoor Division
print(a%b) # Modulus (remainder)
print(a**b) # 10*10 #Exponentiation
print(-a) #unary minus
print(+a) #unary plus
# Out:
# -8
# -12
# -20
# -5.0
# -5
# 0
# 100
# 10
# -10

# %%
# Operator precedence
# paranthesis, power, division, multiplication, add, subtraction (left to right).

a,b=10, 2
# a= a+ b *a - (a**b) # -70
a=a-((a**b)+(a/b))/a #-0.5
print(a)
# Out:
# -0.5

# %%
# Membership Operators

numbers= [2,'3',4]
name= "Saurav"
# # a= "3" in numbers # True
# a= 's' in name # False
# a= 'S' in name # True
# a= 'u' not in name # False
# a= (3+8) not in numbers #True

print(a)
# Out:
# True

# %%
# Assignment Operators

x= 10
# x= x + 1
x += 1
x -= 1
x *= 2
x /= 2
x //= 2
x **= 2
x %=5
print(x)
# Out:
# 0.0

# %%
# Logical Operators - and, or, not

print(True and True) #T
print(True and False) #F
print(False and True) #F
print(False and False) #F

print(True or True) #T
print(True or False) #T
print(False or True) #T
print(False or False) #F
# Out:
# True
# False
# False
# False
# True
# True
# True
# False

# %%
# Identity Operators - is (both variables-objects are pointing to the same location or not), is not

x= 10
y= 10
print(x is y) #True
print(x is not y) #False

x= 10
y= 15
print(x is y) #False
print(x is not y) #True
# Out:
# True
# False
# False
# True

# %%
# Comparision Operators

a=10
b=10
print(a>b)
print(a>=b)
print(a<b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# True
# False
